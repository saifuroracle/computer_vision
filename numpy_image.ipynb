# %%
import numpy as np

# %%
import matplotlib.pyplot as  plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Md. Saifur Rahman.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1500 at 0x24223C82D90>
