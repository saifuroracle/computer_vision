# %%
import numpy as np

# %%
import matplotlib.pyplot as  plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Md. Saifur Rahman.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x300 at 0x24223C82E80>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)
